# %%
## See http://blog.kaggle.com/2017/01/23/a-kaggle-master-explains-gradient-boosting/

# %%
import numpy as np 
import pandas as pd

# %%
data = pd.read_csv("c:/python/data/kaggle.csv")
data
# Out:
#    PersonID  Age  LikesGardening  PlaysVideoGames  LikesHats
# 0         1   13           False             True       True
# 1         2   14           False             True      False
# 2         3   15           False             True      False
# 3         4   25            True             True       True
# 4         5   35           False             True       True
# 5         6   49            True            False      False
# 6         7   68            True             True       True
# 7         8   71            True            False      False
# 8         9   73            True            False       True

# %%
y = data['Age']
X = data.iloc[:, 2:5]

# %%
X = X*1

# %%
X
# Out:
#   LikesGardening PlaysVideoGames LikesHats
# 0              0               1         1
# 1              0               1         0
# 2              0               1         0
# 3              1               1         1
# 4              0               1         1
# 5              1               0         0
# 6              1               1         1
# 7              1               0         0
# 8              1               0         1

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier(max_depth=1, min_samples_split=5, max_features=2) #  min_samples_leaf=4)
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=2, max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=5, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
from sklearn.externals.six import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydotplus  

dot_data = StringIO()
export_graphviz(clf, 
                out_file=dot_data,
                feature_names= X.columns.tolist(),
                class_names= names,
                rounded=True, 
                filled=True, 
                special_characters=True)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
 clf2 = DecisionTreeClassifier(max_depth=4, min_samples_split=2, max_features=2) #  min_samples_leaf=4)
clf2.fit(X, y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=4,
#             max_features=2, max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
from sklearn.externals.six import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydotplus  

dot_data = StringIO()
export_graphviz(clf2, 
                out_file=dot_data,
                feature_names= X.columns.tolist(),
                class_names= names,
                rounded=True, 
                filled=True, 
                special_characters=True)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
names = [str(i) for i in y]
names
# Out:
# ['13', '14', '15', '25', '35', '49', '68', '71', '73']
